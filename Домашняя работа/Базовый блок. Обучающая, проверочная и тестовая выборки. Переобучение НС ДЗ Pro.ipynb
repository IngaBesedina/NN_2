# %% [markdown]
# #Задание

# %% [markdown]
# Используя модуль **datasets** библиотеки **sklearn**, загрузите базу вин (`.load_wine()`).
#
# Используя шаблон ноутбука, выполните загрузку, подготовку и предобработку данных. Обязательное условие: разделение данных на три выборки осуществляется по шаблону (изменять параметры подготовки данных запрещается)!
#
# Проведите серию экспериментов и добейтесь максимальной точности классификации на тестовой выборке выше 94%.
#
# ---
#
# С помощью метода `.summary()` зафиксируйте количество параметров созданной вами нейронной сети.

# %% [markdown]
# #Шаблон ноутбука

# %%
# Последовательная модель НС
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization

# Утилиты для to_categorical()
from tensorflow.keras import utils

# Алгоритмы оптимизации для обучения модели
from tensorflow.keras.optimizers import Adam

# Библиотека для работы с массивами
import numpy as np

# Отрисовка графиков
import matplotlib.pyplot as plt

# Разделение данных на выборки
from sklearn.model_selection import train_test_split

# Для загрузки датасета
from sklearn.datasets import load_wine

# Отрисовка изображений в ноутбуке, а не в консоли или файле
# %matplotlib inline

# %% [markdown]
# ##Описание базы
#
# 1. Датасет состоит из набора данных о винах и их классах.
# 2. Данные по одному вину хранятся в numpy-массиве `x_data`: (`13` параметров).
# 3. В датасете `3` класса вин: `y_data`.
# 4. Количество примеров: `178`.

# %%
x_data = load_wine()['data']              # Загрузка набора данных о винах
y_data = load_wine()['target']            # Загрузка классов вин

print('Размерность x_data -', x_data.shape)
print('Размерность y_data -', y_data.shape)
print()

# Вывод примера данных
print('Данные по первому вину:',x_data[0])
print('Класс вина:',y_data[0])
# Out:
# Размерность x_data - (178, 13)
# Размерность y_data - (178,)
#
# Данные по первому вину: [1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#  2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]
# Класс вина: 0

# %% [markdown]
# ##Подготовка данных

# %%
# Перевод в one hot encoding
y_data = utils.to_categorical(y_data, 3)

# Разбиение наборов на общую и тестовую выборки
x_all, x_test, y_all, y_test = train_test_split(x_data,
                                                y_data,
                                                test_size=0.1,
                                                shuffle=True,
                                                random_state = 6)

# Разбиение общей выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(x_all,
                                                  y_all,
                                                  test_size=0.1,
                                                  shuffle=True,
                                                  random_state = 6)

print(x_train.shape)
print(y_train.shape)
print()
print(x_val.shape)
print(y_val.shape)
# Out:
# (144, 13)
# (144, 3)
#
# (16, 13)
# (16, 3)

# %%
# ваше решение
model = Sequential([
    Dense(128, activation='relu', input_shape=(13,)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(3, activation='softmax')
])

# Компиляция модели
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Обучение модели
history = model.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val), verbose=1)

# Оценка модели
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Вывод структуры модели
model.summary()
# Out:
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.2898 - loss: 1.5828 - val_accuracy: 0.3750 - val_loss: 2.2132
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5072 - loss: 0.9776 - val_accuracy: 0.2500 - val_loss: 4.4017
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6017 - loss: 0.7435 - val_accuracy: 0.2500 - val_loss: 5.0307
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6604 - loss: 0.7440 - val_accuracy: 0.2500 - val_loss: 4.9219
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7244 - loss: 0.6289 - val_accuracy: 0.2500 - val_loss: 4.5936
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6793 - loss: 0.6911 - val_accuracy: 0.2500 - val_loss: 4.2158
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7008 - loss: 0.6585 - val_accuracy: 0.2500 - val_loss: 3.7089
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7105 - loss: 0.7220 - val_accuracy: 0.2500 - val_loss: 3.2789
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7303 - loss: 0.5567 - val_accuracy: 0.2500 - val_loss: 2.8457
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6997 - loss: 0.6205 - val_accuracy: 0.2500 - val_loss: 2.4713
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7623 - loss: 0.5094 - val_accuracy: 0.2500 - val_loss: 2.1669
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7775 - loss: 0.4638 - val_accuracy: 0.2500 - val_loss: 1.9395
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7228 - loss: 0.5905 - val_accuracy: 0.2500 - val_loss: 1.7893
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8077 - loss: 0.4439 - val_accuracy: 0.3125 - val_loss: 1.6642
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7509 - loss: 0.5638 - val_accuracy: 0.3125 - val_loss: 1.5110
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7682 - loss: 0.5402 - val_accuracy: 0.3125 - val_loss: 1.3674
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8257 - loss: 0.4411 - val_accuracy: 0.3750 - val_loss: 1.1802
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8387 - loss: 0.4300 - val_accuracy: 0.4375 - val_loss: 0.9788
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8189 - loss: 0.3806 - val_accuracy: 0.5000 - val_loss: 0.8369
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8443 - loss: 0.4287 - val_accuracy: 0.6250 - val_loss: 0.7095
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9191 - loss: 0.2862 - val_accuracy: 0.6875 - val_loss: 0.6486
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8617 - loss: 0.4011 - val_accuracy: 0.7500 - val_loss: 0.6167
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8692 - loss: 0.3436 - val_accuracy: 0.8125 - val_loss: 0.5812
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8584 - loss: 0.3552 - val_accuracy: 0.8125 - val_loss: 0.5470
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8821 - loss: 0.3487 - val_accuracy: 0.8125 - val_loss: 0.5300
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9096 - loss: 0.3104 - val_accuracy: 0.8125 - val_loss: 0.4844
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8979 - loss: 0.2972 - val_accuracy: 0.8750 - val_loss: 0.4069
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8492 - loss: 0.3674 - val_accuracy: 0.8750 - val_loss: 0.3575
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8779 - loss: 0.3590 - val_accuracy: 0.8125 - val_loss: 0.3815
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9460 - loss: 0.2238 - val_accuracy: 0.8750 - val_loss: 0.3299
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9201 - loss: 0.2312 - val_accuracy: 0.8750 - val_loss: 0.3769
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9400 - loss: 0.2033 - val_accuracy: 0.8750 - val_loss: 0.5089
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8916 - loss: 0.3318 - val_accuracy: 0.8750 - val_loss: 0.3488
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8973 - loss: 0.2717 - val_accuracy: 0.9375 - val_loss: 0.2651
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8847 - loss: 0.2723 - val_accuracy: 0.9375 - val_loss: 0.2646
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9096 - loss: 0.2271 - val_accuracy: 0.8750 - val_loss: 0.3402
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9099 - loss: 0.2279 - val_accuracy: 0.8750 - val_loss: 0.4609
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8704 - loss: 0.2441 - val_accuracy: 0.8750 - val_loss: 0.3475
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9809 - loss: 0.1186 - val_accuracy: 0.9375 - val_loss: 0.2912
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9431 - loss: 0.1547 - val_accuracy: 0.9375 - val_loss: 0.2513
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9340 - loss: 0.1966 - val_accuracy: 0.9375 - val_loss: 0.2788
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9617 - loss: 0.1386 - val_accuracy: 0.9375 - val_loss: 0.3101
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9611 - loss: 0.1564 - val_accuracy: 0.8750 - val_loss: 0.3435
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8995 - loss: 0.2120 - val_accuracy: 0.9375 - val_loss: 0.3166
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9449 - loss: 0.1410 - val_accuracy: 0.8750 - val_loss: 0.4365
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9599 - loss: 0.1588 - val_accuracy: 0.8750 - val_loss: 0.5227
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8841 - loss: 0.2436 - val_accuracy: 0.9375 - val_loss: 0.3704
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9346 - loss: 0.1521 - val_accuracy: 0.9375 - val_loss: 0.3652
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9301 - loss: 0.1893 - val_accuracy: 0.8125 - val_loss: 0.6565
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9002 - loss: 0.2302 - val_accuracy: 0.8125 - val_loss: 0.5477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.9444 - loss: 0.2290
# Test Accuracy: 94.44%
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 128)                 │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 38,219 (149.30 KB)
#  Trainable params: 12,611 (49.26 KB)
#  Non-trainable params: 384 (1.50 KB)
#  Optimizer params: 25,224 (98.54 KB)
